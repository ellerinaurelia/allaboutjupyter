# %%
print ("Data Science Fundamental, UNPRI")

strJudul="Data Science Fundamental"
print(strJudul)

print ("Universitas Prima Indonesia")
print(strJudul+ " \nOleh" + "\nUniversitas Prima Indonesia")
strJudul+ " Oleh" + " Universitas Prima Indonesia"

print(True)
print(5>3)
print(5<4)

print(20)
print(3.14)
print(hex(9))
number = 435
print(number, "Nilai hex=", hex (number))
print(5j)

#List
print([1,2,3,4,5])
print(["satu", "dua", "tiga"])

#Tuple
print((1,2,3,4,5))
print(("satu", "dua", "tiga"))

print({"nama": "Ellerin Aurelia CHowina", "umur":20})

biodata = {"nama": "Ellerin Aurelia CHowina", "umur":20, "Mata Kuliah" :"Data Science"}
print(biodata)
print(type(biodata))

print(set([10,20,30,40,50,60]))

number=12345
print("Variabel Integer :", number)
print(type(number))

nama="Data Science Fundamental"
print("variabel String :", nama)
print(type(nama))

number=12.56
print("variabel Float :", number)
print(type(number))

number=89e-4
print("variabel Float :", number)
print(type(number))

var="12345"
print("Type Data", number, "adalah", type(number))

number=int(number)
print("Type Data", number, "adalah", type(number))
# Out:
# Data Science Fundamental, UNPRI
# Data Science Fundamental
# Universitas Prima Indonesia
# Data Science Fundamental
# Oleh
# Universitas Prima Indonesia
# True
# True
# False
# 20
# 3.14
# 0x9
# 435 Nilai hex= 0x1b3
# 5j
# [1, 2, 3, 4, 5]
# ['satu', 'dua', 'tiga']
# (1, 2, 3, 4, 5)
# ('satu', 'dua', 'tiga')
# {'nama': 'Ellerin Aurelia CHowina', 'umur': 20}
# {'nama': 'Ellerin Aurelia CHowina', 'umur': 20, 'Mata Kuliah': 'Data Science'}
# <class 'dict'>
# {40, 10, 50, 20, 60, 30}
# Variabel Integer : 12345
# <class 'int'>
# variabel String : Data Science Fundamental
# <class 'str'>
# variabel Float : 12.56
# <class 'float'>
# variabel Float : 0.0089
# <class 'float'>
# Type Data 0.0089 adalah <class 'float'>
# Type Data 0 adalah <class 'int'>
