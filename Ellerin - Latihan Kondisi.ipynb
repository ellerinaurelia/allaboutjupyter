# %%
# Mengambil input dari user
bil1 = int(input("Masukkan bilangan pertama: "))
bil2 = int(input("Masukkan bilangan kedua: "))

# Menentukan terbesar dan terkecil
terbesar = max(bil1, bil2)
terkecil = min(bil1, bil2)

print(f"Bilangan Terbesar: {terbesar}")
print(f"Bilangan Terkecil: {terkecil}")
# Out:
# Masukkan bilangan pertama:  95
# Masukkan bilangan kedua:  80
# Bilangan Terbesar: 95
# Bilangan Terkecil: 80

# %%
def cek(angka):
    if angka % 2 == 0:
        return "Genap"
    else:
        return "Ganjil"

# Penggunaan fungsi
nilai = int(input("Masukkan sebuah angka: "))
hasil = cek(nilai)
print(f"Angka {nilai} adalah bilangan {hasil}")
# Out:
# Masukkan sebuah angka:  11
# Angka 11 adalah bilangan Ganjil

# %%
# Input Data
nama = input("Nama Mahasiswa : ")
absensi = float(input("Nilai Absensi  : "))
tugas = float(input("Nilai Tugas    : "))
mid = float(input("Nilai MID      : "))
uas = float(input("Nilai UAS      : "))

# Proses Perhitungan
nilai_akhir = (absensi * 0.1) + (tugas * 0.1) + (mid * 0.35) + (uas * 0.45)

# Penentuan Keterangan
if nilai_akhir >= 50:
    keterangan = "Lulus"
else:
    keterangan = "Tidak Lulus"

# Output
print("-" * 20)
print(f"Nama Mahasiswa : {nama}")
print(f"Nilai Absensi  : {absensi}")
print(f"Nilai Tugas    : {tugas}")
print(f"Nilai MID      : {mid}")
print(f"Nilai UAS      : {uas}")
print(f"Nilai Akhir    : {nilai_akhir}")
print(f"Keterangan     : {keterangan}")
# Out:
# Nama Mahasiswa :  12
# Nilai Absensi  :  85
# Nilai Tugas    :  80
# Nilai MID      :  100
# Nilai UAS      :  92
# --------------------
# Nama Mahasiswa : 12
# Nilai Absensi  : 85.0
# Nilai Tugas    : 80.0
# Nilai MID      : 100.0
# Nilai UAS      : 92.0
# Nilai Akhir    : 92.9
# Keterangan     : Lulus

# %%
print("=== Program Operator ===")
num1 = float(input("Masukkan nilai pertama: "))
num2 = float(input("Masukkan nilai kedua: "))

print("\nPilih Operator:")
print("1. Penjumlahan (+)")
print("2. Pengurangan (-)")
print("3. Perkalian (*)")
print("4. Pembagian (/)")

pilihan = input("Pilih (1/2/3/4): ")

if pilihan == '1':
    hasil = num1 + num2
    print(f"Hasil: {num1} + {num2} = {hasil}")
elif pilihan == '2':
    hasil = num1 - num2
    print(f"Hasil: {num1} - {num2} = {hasil}")
elif pilihan == '3':
    hasil = num1 * num2
    print(f"Hasil: {num1} * {num2} = {hasil}")
elif pilihan == '4':
    if num2 != 0:
        hasil = num1 / num2
        print(f"Hasil: {num1} / {num2} = {hasil}")
    else:
        print("Kesalahan: Tidak dapat membagi dengan nol!")
else:
    print("Pilihan tidak valid.")
# Out:
# === Program Operator ===
# Masukkan nilai pertama:  100
# Masukkan nilai kedua:  95
# Pilih Operator:
# 1. Penjumlahan (+)
# 2. Pengurangan (-)
# 3. Perkalian (*)
# 4. Pembagian (/)
# Pilih (1/2/3/4):  4
# Hasil: 100.0 / 95.0 = 1.0526315789473684
